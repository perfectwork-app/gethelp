# %% [markdown]
# This is routine by using Odooly module

# %%
from odooly import Client, Env

source_connection = Client(server='https://skinequality.com', db='PW3-SKNEQY', user='admin.synercatalyst', password='Wengseng1@')

print(source_connection.db.server_version())
res_partner_obj = source_connection.env['res.partner']

results = res_partner_obj.search([(1,'=',1)])

for line in results:
    if line.country_id:
        if line.country_id.name == 'Singapore':
            print(line.name)
            line.country_id = False
# Out:
# 13.0
# 5 Senses Spa
# 8 Medi-Aesthetics (Orchard) Pte Ltd
# Ezyhealth Holdings Pte Ltd
# Abirra Bridal & Beauty Creation
# Absolute Aesthetique Pte Ltd
# Adel Cosmeceutical Centre Pte Ltd
# Adeline Face & Body
# Aesthetics Beauty House Pte Ltd
# Aesthetics Face & Body Spa
# Aesthetics Mktg Asia P/L
# Aileen Beauty
# Ainee Beauty & Wellness
# Airellis
# Airellis Claire De Beaute
# Airellis Esthetics & Wellness Studio
# Alexis Beauty Salon
# Alicia Beauty Skin Care
# ALLURE Beata Beauty Pte. Ltd.
# Ally Beauty Pte Ltd
# Alsis De Beaute
# Alternate Wellness Holdings (HAACH)
# Amanda Asthetique
# Amaryllis Beauty
# Amaryllis Face & Body Care
# A-Mei Beauty Spa LLP
# AMES United
# AM Seasons Enterprise
# ANew Me Beauty Aesthetic Pte Ltd
# Anew Pte Ltd
# Angel Artz
# Angel Beauty Hut
# Angel Fair Beauty
# Angel Professional
# Angels Beauty Hub
# Apex Cosmeceutical Centre (Katong)
# Apex Cosmeceutical Centre Pte Ltd (Jurong)
# Apex Cosmeceutical Centre (Rochor) Pte Ltd
# ...
